# %% [markdown]
# ## Regex (Regular Expression)

# %%
import re

# %%
txt = '123jdaifde233'
result = re.match(r"^\d+",txt)
print(result.group())


# import re
# txt = "123jdaifde233"
# match = re.match(r"^\d+", txt)

# print(match.group())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 txt = '123jdaifde233'
#       2 result = re.match(r"^{\d}+",txt)
# ----> 3 print(result.group())
#       6 # import re
#       7 # txt = "123jdaifde233"
#       8 # match = re.match(r"^\d+", txt)
#       9
#      10 # print(match.group())
#
# AttributeError: 'NoneType' object has no attribute 'group'
