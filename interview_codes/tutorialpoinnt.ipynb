# %%
st = "Welcome To TutorialsPoint"

print(type(st))
# Out:
# <class 'str'>

# %%
print(st[2:5])
# Out:
# 'tnioPslairotuT oT emocleW'

# %%
tup= (['One', 'Two', 'Three'], 1,2.0,3, (1.0, 2.0, 3.0))
print(type(tup))
# Out:
# <class 'tuple'>

# %%
print(tup[0])
print(tup[0][2])
print(tup[2])
# Out:
# ['One', 'Two', 'Three']
# Three
# 2.0

# %%
def bitadd(a,b):
    carry=0
    while(b!=0):
        carry=a&b
        carry=carry<<1
        a=a^b
        b=carry
    return a

print(bitadd(4,5))
# Out:
# 9

# %%
lis=[65,97]

for i in lis:
    print(chr(i))
    print(str(i))
print(ord('A'))
# Out:
# A
# 65
# a
# 97
# 65

# %%
print(int('101',2))
# Out:
# 5

# %%
print('101',2)
# Out:
# 101 2

# %% [markdown]
# List

# %%
ls = ['math','chemistery',1997,2000]
ls.append(100)
print(ls)

ls.pop(3)
print(ls)

print(ls.index(100))
print(ls.pop())
print(ls)

print(ls.append(2000))
print(ls.append(100))
print(ls)

ls1 = ls.copy()
print(ls1)
print(ls1.clear())
print(ls1)

print(ls.count(1))
print(ls.count(100))

ls.append(100)
ls.append(100)
ls.append(100)
print(ls.count(100))

ls1 = ls.copy()
print(ls.extend(ls1))
print(ls)

print(ls+ls1)
print(ls.append(ls1))
print(ls)

print(ls.insert(0,100))
print(ls)

print(ls.reverse())
print(ls)

print(ls.reverse())
print(ls)

ls=ls[0:10]
print(ls)
# Out:
# ['math', 'chemistery', 1997, 2000, 100]
# ['math', 'chemistery', 1997, 100]
# 3
# 100
# ['math', 'chemistery', 1997]
# None
# None
# ['math', 'chemistery', 1997, 2000, 100]
# ['math', 'chemistery', 1997, 2000, 100]
# None
# []
# 0
# 1
# 4
# None
# ['math', 'chemistery', 1997, 2000, 100, 100, 100, 100, 'math', 'chemistery', 1997, 2000, 100, 100, 100, 100]
# ['math', 'chemistery', 1997, 2000, 100, 100, 100, 100, 'math', 'chemistery', 1997, 2000, 100, 100, 100, 100, 'math', 'chemistery', 1997, 2000, 100, 100, 100, 100]
# None
# ['math', 'chemistery', 1997, 2000, 100, 100, 100, 100, 'math', 'chemistery', 1997, 2000, 100, 100, 100, 100, ['math', 'chemistery', 1997, 2000, 100, 100, 100, 100]]
# None
# [100, 'math', 'chemistery', 1997, 2000, 100, 100, 100, 100, 'math', 'chemistery', 1997, 2000, 100, 100, 100, 100, ['math', 'chemistery', 1997, 2000, 100, 100, 100, 100]]
# None
# ...

# %%
ls[0]=1000
print(ls)
print(ls[4:7])
print(ls[5:1])
print(ls[5:1:-1])
print(ls[1:5:-1])
print(ls[-1:-5:-1])
print(ls[-1:5])
print(ls[-5:-1])
print(ls[-1:5:-1])
print(ls[-5:-1:-1])
print(ls[-6:-1:-1])
print(ls[-1:-6:-1])
print(ls[-6:-1:-1])
print(ls[-1:-6:-1])
print(ls[::-1])
print(ls)
del ls[1:5]
print(ls)
del ls[-2:-1:-1]
# Out:
# [1000, 'math']
# []
# []
# []
# []
# ['math', 1000]
# ['math']
# [1000]
# []
# []
# []
# ['math', 1000]
# []
# ['math', 1000]
# ['math', 1000]
# [1000, 'math']
# [1000]

# %%
ls=[1,2,3,4,5,6,7,8,9]
ls2=[100,101,102,103,104,105]
ls[2:2]=ls2
print(ls)

res = [(lambda x:x**2)(x)  for x in ls]
print(res)
# Out:
# [1, 2, 100, 101, 102, 103, 104, 105, 3, 4, 5, 6, 7, 8, 9]
# [1, 4, 10000, 10201, 10404, 10609, 10816, 11025, 9, 16, 25, 36, 49, 64, 81]

# %%
string = 'Hell313o Abh42ay323424'
res= [i.upper() for i in string if i.isalpha()]
print(res)
res1 = "".join(res)
print(res1)

res2 = [i for i in string if i.isalnum()]
print(res2)
# Out:
# ['H', 'E', 'L', 'L', 'O', 'A', 'B', 'H', 'A', 'Y']
# HELLOABHAY
# ['H', 'e', 'l', 'l', '3', '1', '3', 'o', 'A', 'b', 'h', '4', '2', 'a', 'y', '3', '2', '3', '4', '2', '4']

# %%
import copy
ls = [1,2,3,4,5]
ls1 = copy.deepcopy(ls)
print(id(ls[2]))
print(id(ls1[2]))
print(id(ls))
print(id(ls1))
ls1[0]=100
print(ls)
print(ls1)


ls = [[1,2],[3,4],3,4]
ls1 = copy.copy(ls)
print(id(ls[0]))
print(id(ls1[0]))
ls1[1][0]=100
print(ls)
print(ls1)
# Out:
# 140708748395496
# 140708748395496
# 2002916779136
# 2002915068096
# [1, 2, 3, 4, 5]
# [100, 2, 3, 4, 5]
# 2002916606464
# 2002916606464
# [[1, 2], [100, 4], 3, 4]
# [[1, 2], [100, 4], 3, 4]

# %%
import copy

ls = [[1], [2]]
ls1 = copy.deepcopy(ls)

print(id(ls))
print(id(ls1))

print(id(ls[0][0]))
print(id(ls1[0][0]))
# Out:
# 2002916798976
# 2002916801600
# 140708748395432
# 140708748395432

# %% [markdown]
# ************  Tuple  *************

# %%
tup = ('physics','chemistry',1997,2000)

# %%
print(tup)
# Out:
# ('physics', 'chemistry', 1997, 2000)

# %%
tup[1]
# Out:
# 'chemistry'

# %%
tup[1]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 tup[1]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup1=(1,2,3)
tup2=(4,5,6)

# %%
tup3 = tup1+tup2
print(tup3)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
del tup3
print(tup3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 del tup3
# ----> 2 print(tup3)
#
# NameError: name 'tup3' is not defined

# %%
print(tup1==tup2)
# Out:
# False

# %%
tup1=(1,2,3)
tup2=(1,2,3)
print(tup1==tup2)
# Out:
# True

# %%
print(len(tup1))
# Out:
# 3

# %%
print(max(tup1))
# Out:
# 3

# %%
print(min(tup1))
# Out:
# 1

# %%
lis=[1,2,3,4,5]
print(type(lis))
tup = tuple(lis)
print(type(tup))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
tup=(1,2,3,4,5)
lis = list(tup)
print(type(tup))
print(type(lis) )
# Out:
# <class 'tuple'>
# <class 'list'>

# %%
# tup[0]=100
lis[0]=100
tup = tuple(lis)
print(tup)
# Out:
# (100, 2, 3, 4, 5)

# %%
print(tup[:4])
print(tup[3:4])
# Out:
# (100, 2, 3, 4)
# (4,)

# %%
print(tup[2:4])
# Out:
# (3, 4)

# %%
tup = (1,2,3,4,5)
tup[-2:-1]
tup[-1:2]
tup[-1:-2]
tup[2:5:-1]
# tup[2:-1]
# Out:
# ()

# %%
lis = [1,2,3]
x,y,z=lis
print(x,y,z)
print("X : ",x)
x
# Out:
# 1 2 3
# X :  1
# 1

# %%
lis=[1,2,3,4,5,6]
# x,y=lis
x,*y=lis
print("x : ",x)
print("y : ",y)
print(type(x))
print(type(y))
x,y
# Out:
# x :  1
# y :  [2, 3, 4, 5, 6]
# <class 'int'>
# <class 'list'>
# (1, [2, 3, 4, 5, 6])

# %%
tup1 = (10,20,30, 40, 50, 60)
*x, y, z = tup1
print ("x: ",x, "y: ", y, "z: ", z)
# Out:
# x:  [10, 20, 30, 40] y:  50 z:  60

# %%
tup = (1,2,3,4,5,6)
for i in tup:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
import collections

# %%
st = {}
type(st)
# Out:
# dict

# %%
st = set()
type(st)
# Out:
# set

# %%
st = {1}
type(st)
# Out:
# set

# %%
my_set = set([1, 2, 3, 4, 5])
print (my_set)
type(my_set)
# Out:
# {1, 2, 3, 4, 5}
# set

# %%
my_set = set((1, 2, 3, 4, 5))
print (my_set)
type(my_set)
# Out:
# {1, 2, 3, 4, 5}
# set

# %%
my_set={1,2,3,4}
my_set.add(4)
print(my_set)
# Out:
# {1, 2, 3, 4}

# %%
my_set={1,2,3,4}
my_set.remove(4)
print(my_set)
# Out:
# {1, 2, 3}

# %%
my_set = {1, 2, 3, 4}
# No error even if 5 is not in the set
my_set.discard(5)  
print (my_set)
# Out:
# {1, 2, 3, 4}

# %%
my_set = {1, 2, 3, 4}
if 2 in my_set:
   print("2 is present in the set")
else:
   print("2 is not present in the set")
# Out:
# 2 is present in the set

# %%
st={1,2,3}
st1 = {1,2,3}
nested_set={(i,j) for i in st for j in st1}
print(nested_set)
# Out:
# {(1, 2), (2, 1), (3, 1), (1, 1), (2, 3), (3, 3), (2, 2), (3, 2), (1, 3)}

# %%
my_forezen_set = frozenset([1,2,3,4])
print(my_forezen_set)
# Out:
# frozenset({1, 2, 3, 4})

# %%
frozenset.add(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 frozenset.add(4)
#
# AttributeError: type object 'frozenset' has no attribute 'add'

# %%
my_set = {1, 2, 3}
my_set.update([0])
print(my_set)
# Out:
# {0, 1, 2, 3}

# %%
lst = [3,1,4]
# lst.sort()
# print(lst)

lst1 = sorted(lst)
print(lst)
print(lst1)
# Out:
# [3, 1, 4]
# [1, 3, 4]

# %%
st1={1,2,3,4}
st2={3,4,5,6}

st = st1&st2
print(st)
# Out:
# {3, 4}

# %%
st  = st1^st2
print(st)
# Out:
# {1, 2, 5, 6}

# %%
st = st1 | st2
print(st)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
lst=[1,2,3,4]
lst1 = lst.copy()
print(lst1)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# <!-- Dictionaries -->

# %%
dic={'a':1,'b':2,'c':3}
# dic.clear()
# print(dic)
dic1 = dic.copy()
print(dic1['a'])
# Out:
# 1

# %%
print(dic.items())
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 3)])

# %%
for  i,j in dic.items():
    print(i,j)
# Out:
# a 1
# b 2
# c 3

# %%
print(hash('a'))
# Out:
# -5147833444432643553

# %%
for i in dic:
    print(i)
    print(dic.get(i))
# Out:
# a
# 1
# b
# 2
# c
# 3

# %%
dic={'a':1,'b':2,'c':3}
print(dic.setdefault('a'))
# Out:
# 1

# %%
print(dic.setdefault('d',0))
print(dic)
# Out:
# 0
# {'a': 1, 'b': 2, 'c': 3, 'd': 0}

# %%
dic={'a':1,'b':2,'c':3}
dic1 = {'d':4,'e':5,'f':6}
dic.update(dic1)
print(dic)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}

# %%
print(dic.values())
# Out:
# dict_values([1, 2, 3, 4, 5, 6])

# %%
for i in dic.values():
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
