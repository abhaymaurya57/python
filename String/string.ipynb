# %%
st = "Hello Abhay"

# %%
print(st.capitalize())
# Out:
# Hello abhay

# %%
print(st.casefold())
# Out:
# hello abhay

# %%
print(st.isdigit())
# Out:
# False

# %%
print(st.isalpha())
# Out:
# False

# %%
print(st.islower())
# Out:
# False

# %%
print(st.isascii())
# Out:
# True

# %%
for i in st:
    # print(i)
    # a = chr(65)
    # print(a)
    # print(ascii(i))
    print(ord(i))
    # print(chr(a))
# Out:
# 72
# 101
# 108
# 108
# 111
# 32
# 65
# 98
# 104
# 97
# 121

# %%
print(st.center(30,'.'))
# Out:
# .........Hello Abhay..........

# %%
print(st.count('a'))
print(st.count('l'))
# Out:
# 1
# 2

# %%
print(st.encode(encoding='utf-8',errors='strict'))
# Out:
# b'Hello Abhay'

# %%
print(st.endswith('ay'))
# Out:
# True

# %%
print(st.startswith("He"))
# Out:
# True

# %%
print(st.find("ay"))
print(st.find('A',0,7))
# Out:
# 9
# 6

# %%
name = "Abhay"
age = 30
result = 'My name : {}, Age: {}'.format(name,age)
print(result)
# Out:
# My name : Abhay, Age: 30

# %%
print(st.find("a"))
# Out:
# 9

# %%
print(st.rfind('a'))
# Out:
# 9

# %%
print(st.rindex('a'))
# Out:
# 9

# %%
s = "abhaymaurya57"
print(s.isalnum())
# Out:
# True

# %%
s='Abhay Maurya'
print(s.isalpha())
# Out:
# False

# %%
s='AbhayMaurya'
print(s.isalpha())
# Out:
# True

# %%
n ='434433'
print(n.isdecimal())
# Out:
# True

# %%
star='*'
a1='1234'
c=star.join(a1)
print(c)
d = " ".join(a1)
print(d)
# Out:
# 1*2*3*4
# 1 2 3 4

# %%
print(st.lower())
# Out:
# hello abhay

# %%
print(st.upper())
# Out:
# HELLO ABHAY

# %%
print(st.capitalize())
# Out:
# Hello abhay

# %%
s="    abhay maurya     "
print(s)
print(s.lstrip())
print(s)
print(s.rstrip())
print(s.strip())
# Out:
#     abhay maurya
# abhay maurya
#     abhay maurya
#     abhay maurya
# abhay maurya
